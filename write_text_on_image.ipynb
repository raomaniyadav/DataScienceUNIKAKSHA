# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import cv2

# %%
def show(img):
    plt.imshow(img)
    plt.xticks([])
    plt.yticks([])
    plt.show()

# %%
imag1=cv2.imread("C:\\Users\\Yadav\\Pictures\\ashwini-chaudhary-4SqmKiyeXbE-unsplash (2).jpg",flags=cv2.IMREAD_GRAYSCALE)

# %%
show(imag1)

# %%
d=np.ones([400,400,3],dtype=np.uint8)
d=d*255

# %%
#cv2.imshow("white image",d)

# %%
show(d)

# %%
image = cv2.putText(d, text='OpenCV', org=(100,200),  fontFace= cv2.FONT_HERSHEY_SIMPLEX, 
                   fontScale=2,color=[252,6,20], thickness=3)

# %%
show(image)

# %%
plt.imsave("image.jpeg",image)
